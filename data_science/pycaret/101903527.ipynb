# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pycaret=='2.3.4' &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %%
from pycaret.utils import version
version()
# Out:
# '2.3.6'

# %%
import numpy as np
import pandas as pd
import os
import sys
import pytz

# %%
#file_name=sys.argv[1]
file_name='/content/drive/Othercomputers/My Laptop/New Volume [E]/6th sem/predictive_analysis/assignments/ass3/101903527.csv'
df=pd.read_csv(file_name,nrows=50)
df=df.drop(['Peptide Sequence'],axis=1)
print(df.head())
from pycaret.classification import *
setup(data=df, target='target',silent=True)
cm=compare_models()
print(cm)
df2=pull()
print(df2)
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# qda       Quadratic Discriminant Analysis    0.6917  0.7000    0.70  0.8000
# lda          Linear Discriminant Analysis    0.6667  0.6500    0.65  0.6333
# et                 Extra Trees Classifier    0.6667  0.8500    0.70  0.6833
# nb                            Naive Bayes    0.6500  0.5875    0.50  0.7167
# rf               Random Forest Classifier    0.6167  0.7250    0.80  0.7000
# ridge                    Ridge Classifier    0.5833  0.0000    0.75  0.6167
# knn                K Neighbors Classifier    0.5333  0.5250    0.55  0.5500
# ada                  Ada Boost Classifier    0.5333  0.5750    0.45  0.4500
# lightgbm  Light Gradient Boosting Machine    0.5333  0.5000    1.00  0.5333
# dummy                    Dummy Classifier    0.5333  0.5000    1.00  0.5333
# lr                    Logistic Regression    0.5000  0.6750    0.50  0.4333
# dt               Decision Tree Classifier    0.5000  0.5000    0.55  0.4500
# gbc          Gradient Boosting Classifier    0.5000  0.5375    0.60  0.4833
# svm                   SVM - Linear Kernel    0.4667  0.0000    0.60  0.3000
#
#               F1  Kappa     MCC  TT (Sec)
# qda       0.7033   0.37  0.4077     0.015
# lda       0.6100   0.32  0.3500     0.013
# et        0.6433   0.33  0.3809     0.412
# nb        0.5467   0.26  0.3155     0.013
# rf        0.6800   0.23  0.2655     0.462
# ridge     0.6600   0.10  0.1000     0.013
# knn       0.5200   0.03  0.0500     0.146
# ada       0.4133   0.09  0.1155     0.086
# lightgbm  0.6867   0.00  0.0000     0.051
# dummy     0.6867   0.00  0.0000     0.011
# lr        0.4400   0.01  0.0000     0.830
# dt        0.4700   0.02  0.0000     0.014
# gbc       0.5033   0.08  0.0500     0.070
# svm       0.3933   0.00  0.0000     0.016
# QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001)
#                                     Model  Accuracy  ...     MCC  TT (Sec)
# qda       Quadratic Discriminant Analysis    0.6917  ...  0.4077     0.015
# lda          Linear Discriminant Analysis    0.6667  ...  0.3500     0.013
# et                 Extra Trees Classifier    0.6667  ...  0.3809     0.412
# nb                            Naive Bayes    0.6500  ...  0.3155     0.013
# rf               Random Forest Classifier    0.6167  ...  0.2655     0.462
# ridge                    Ridge Classifier    0.5833  ...  0.1000     0.013
# knn                K Neighbors Classifier    0.5333  ...  0.0500     0.146
# ada                  Ada Boost Classifier    0.5333  ...  0.1155     0.086
# lightgbm  Light Gradient Boosting Machine    0.5333  ...  0.0000     0.051
# dummy                    Dummy Classifier    0.5333  ...  0.0000     0.011
# lr                    Logistic Regression    0.5000  ...  0.0000     0.830
# dt               Decision Tree Classifier    0.5000  ...  0.0000     0.014
# gbc          Gradient Boosting Classifier    0.5000  ...  0.0500     0.070
# svm                   SVM - Linear Kernel    0.4667  ...  0.0000     0.016
#
# [14 rows x 9 columns]

# %%
dfmod=df2['Model']
dfacc=df2['Accuracy']

# %%
setup(data=df, target='target', normalize = True, normalize_method = 'zscore', silent=True)
cm = compare_models()
df3=pull()
dfacc1=df3['Accuracy']
# Out:
#                                     Model  Accuracy    AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.5333  0.575    0.40  0.4167
# lda          Linear Discriminant Analysis    0.5333  0.450    0.50  0.3833
# lightgbm  Light Gradient Boosting Machine    0.5333  0.500    0.00  0.0000
# dummy                    Dummy Classifier    0.5333  0.500    0.00  0.0000
# ridge                    Ridge Classifier    0.5083  0.000    0.40  0.3500
# svm                   SVM - Linear Kernel    0.4917  0.000    0.40  0.3167
# qda       Quadratic Discriminant Analysis    0.4667  0.425    0.40  0.3333
# et                 Extra Trees Classifier    0.4500  0.425    0.40  0.3000
# nb                            Naive Bayes    0.3917  0.400    0.50  0.3667
# gbc          Gradient Boosting Classifier    0.3917  0.250    0.30  0.3333
# dt               Decision Tree Classifier    0.3750  0.350    0.40  0.2833
# rf               Random Forest Classifier    0.3583  0.325    0.30  0.2333
# ada                  Ada Boost Classifier    0.3583  0.225    0.35  0.3333
# knn                K Neighbors Classifier    0.3167  0.325    0.30  0.2167
#
#               F1  Kappa     MCC  TT (Sec)
# lr        0.3800   0.02  0.0500     0.022
# lda       0.4133  -0.02  0.0000     0.015
# lightgbm  0.0000   0.00  0.0000     0.019
# dummy     0.0000   0.00  0.0000     0.012
# ridge     0.3667  -0.06 -0.0577     0.015
# svm       0.3467  -0.11 -0.0923     0.015
# qda       0.3467  -0.14 -0.1500     0.014
# et        0.3333  -0.17 -0.1655     0.411
# nb        0.4067  -0.19 -0.2077     0.014
# gbc       0.2900  -0.21 -0.2077     0.070
# dt        0.3200  -0.28 -0.3077     0.014
# rf        0.2567  -0.34 -0.3732     0.463
# ada       0.3233  -0.30 -0.3077     0.086
# knn       0.2400  -0.36 -0.4155     0.115

# %%
setup(data=df, target='target', normalize = True, normalize_method = 'minmax', silent=True)
cm = compare_models()
df4=pull()
dfacc2=df4['Accuracy']
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# et                 Extra Trees Classifier    0.5833  0.5500    0.70  0.6333
# ridge                    Ridge Classifier    0.5333  0.0000    0.55  0.4833
# qda       Quadratic Discriminant Analysis    0.5250  0.5750    0.70  0.5500
# knn                K Neighbors Classifier    0.5167  0.5125    0.60  0.5667
# gbc          Gradient Boosting Classifier    0.5000  0.5500    0.50  0.5167
# dt               Decision Tree Classifier    0.4917  0.5000    0.40  0.3667
# lr                    Logistic Regression    0.4833  0.4500    0.60  0.4667
# svm                   SVM - Linear Kernel    0.4833  0.0000    0.55  0.4333
# lda          Linear Discriminant Analysis    0.4750  0.4500    0.45  0.3667
# nb                            Naive Bayes    0.4583  0.5125    0.25  0.2000
# ada                  Ada Boost Classifier    0.4417  0.4500    0.50  0.3333
# lightgbm  Light Gradient Boosting Machine    0.4000  0.5000    0.30  0.1000
# dummy                    Dummy Classifier    0.4000  0.5000    0.30  0.1000
# rf               Random Forest Classifier    0.3750  0.3125    0.50  0.3667
#
#               F1  Kappa     MCC  TT (Sec)
# et        0.6333   0.18  0.2000     0.408
# ridge     0.4933   0.10  0.1155     0.013
# qda       0.5733   0.13  0.1423     0.014
# knn       0.5567   0.00 -0.0000     0.116
# gbc       0.4800   0.06  0.0500     0.069
# dt        0.3633  -0.00  0.0077     0.014
# lr        0.4933  -0.00  0.0155     0.019
# svm       0.4500   0.05  0.0500     0.014
# lda       0.3900   0.02 -0.0077     0.015
# nb        0.2167  -0.01 -0.0077     0.015
# ada       0.3700  -0.05 -0.0577     0.087
# lightgbm  0.1500   0.00  0.0000     0.021
# dummy     0.1500   0.00  0.0000     0.011
# rf        0.4100  -0.28 -0.2923     0.460

# %%
setup(data=df, target='target', normalize = True, normalize_method = 'maxabs', silent=True)
cm = compare_models()
df5=pull()
dfacc3=df5['Accuracy']
# Out:
#                                     Model  Accuracy    AUC  Recall   Prec.  \
# ridge                    Ridge Classifier    0.6083  0.000    0.65  0.6500
# knn                K Neighbors Classifier    0.5917  0.550    0.70  0.6167
# lr                    Logistic Regression    0.5667  0.625    0.65  0.6000
# qda       Quadratic Discriminant Analysis    0.5667  0.575    0.55  0.6333
# lightgbm  Light Gradient Boosting Machine    0.5667  0.500    1.00  0.5667
# dummy                    Dummy Classifier    0.5667  0.500    1.00  0.5667
# gbc          Gradient Boosting Classifier    0.5500  0.525    0.70  0.6167
# dt               Decision Tree Classifier    0.5167  0.500    0.55  0.5000
# svm                   SVM - Linear Kernel    0.5167  0.000    0.55  0.5667
# ada                  Ada Boost Classifier    0.5167  0.500    0.60  0.5167
# rf               Random Forest Classifier    0.4917  0.600    0.60  0.5000
# et                 Extra Trees Classifier    0.4667  0.550    0.55  0.5000
# lda          Linear Discriminant Analysis    0.4333  0.525    0.55  0.5500
# nb                            Naive Bayes    0.3167  0.325    0.40  0.3500
#
#               F1  Kappa     MCC  TT (Sec)
# ridge     0.6200   0.27  0.2577     0.013
# knn       0.6333   0.16  0.1577     0.117
# lr        0.6033   0.17  0.1500     0.020
# qda       0.5567   0.12  0.1500     0.015
# lightgbm  0.7167   0.00  0.0000     0.021
# dummy     0.7167   0.00  0.0000     0.011
# gbc       0.6300   0.03  0.0500     0.070
# dt        0.5033   0.01 -0.0155     0.016
# svm       0.5167   0.09  0.1155     0.015
# ada       0.5333   0.05  0.0500     0.087
# rf        0.5200  -0.00 -0.0077     0.467
# et        0.5000  -0.03 -0.0500     0.410
# lda       0.4967  -0.10 -0.0845     0.014
# nb        0.3667  -0.43 -0.4500     0.013

# %%
setup(data=df, target='target', normalize = True, normalize_method = 'robust', silent=True)
cm = compare_models()
df6=pull()
dfacc4=df6['Accuracy']
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.6667  0.6000    0.65  0.7167
# lda          Linear Discriminant Analysis    0.6083  0.5000    0.60  0.6333
# lightgbm  Light Gradient Boosting Machine    0.5333  0.5000    1.00  0.5333
# dummy                    Dummy Classifier    0.5333  0.5000    1.00  0.5333
# knn                K Neighbors Classifier    0.5250  0.4625    0.60  0.5167
# qda       Quadratic Discriminant Analysis    0.5250  0.5500    0.50  0.5167
# ridge                    Ridge Classifier    0.5083  0.0000    0.95  0.5167
# nb                            Naive Bayes    0.4833  0.5750    0.85  0.4667
# rf               Random Forest Classifier    0.4833  0.5500    0.45  0.5167
# et                 Extra Trees Classifier    0.4833  0.7500    0.40  0.5500
# ada                  Ada Boost Classifier    0.4583  0.5000    0.40  0.4000
# svm                   SVM - Linear Kernel    0.4500  0.0000    0.45  0.4833
# dt               Decision Tree Classifier    0.4083  0.4250    0.40  0.3667
# gbc          Gradient Boosting Classifier    0.4000  0.4500    0.35  0.3500
#
#               F1  Kappa     MCC  TT (Sec)
# lr        0.6633   0.25  0.2655     0.016
# lda       0.5933   0.21  0.2232     0.034
# lightgbm  0.6867   0.00  0.0000     0.021
# dummy     0.6867   0.00  0.0000     0.011
# knn       0.5467   0.02  0.0077     0.117
# qda       0.4800   0.13  0.1077     0.013
# ridge     0.6600  -0.05 -0.0577     0.015
# nb        0.5933  -0.10 -0.1155     0.016
# rf        0.4633  -0.02 -0.0345     0.461
# et        0.4367  -0.00  0.0155     0.432
# ada       0.3867  -0.06 -0.0923     0.087
# svm       0.4400  -0.05 -0.0500     0.013
# dt        0.3633  -0.12 -0.1577     0.014
# gbc       0.3367  -0.23 -0.2500     0.126

# %%
dfout=pd.DataFrame({
    'Accuracy wihout Normalization':list(dfacc),
    'Accuracy with zscore Normalization':list(dfacc1),
    'Accuracy with minmax Normalization':list(dfacc2),
    'Accuracy with maxabs Normalization':list(dfacc3),
    'Accuracy with robust Normalization':list(dfacc4),
},index=dfmod)
print(dfout)
# Out:
#                                  Accuracy wihout Normalization  ...  Accuracy with robust Normalization
# Model                                                           ...
# Quadratic Discriminant Analysis                         0.6917  ...                              0.6667
# Linear Discriminant Analysis                            0.6667  ...                              0.6083
# Extra Trees Classifier                                  0.6667  ...                              0.5333
# Naive Bayes                                             0.6500  ...                              0.5333
# Random Forest Classifier                                0.6167  ...                              0.5250
# Ridge Classifier                                        0.5833  ...                              0.5250
# K Neighbors Classifier                                  0.5333  ...                              0.5083
# Ada Boost Classifier                                    0.5333  ...                              0.4833
# Light Gradient Boosting Machine                         0.5333  ...                              0.4833
# Dummy Classifier                                        0.5333  ...                              0.4833
# Logistic Regression                                     0.5000  ...                              0.4583
# Decision Tree Classifier                                0.5000  ...                              0.4500
# Gradient Boosting Classifier                            0.5000  ...                              0.4083
# SVM - Linear Kernel                                     0.4667  ...                              0.4000
#
# [14 rows x 5 columns]

# %%
dfout.to_csv('/content/drive/Othercomputers/My Laptop/New Volume [E]/6th sem/predictive_analysis/assignments/ass3/output-101903527-Normalization.csv')

# %% [markdown]
# Q2

# %%
#file_name=sys.argv[1]
file_name='/content/drive/Othercomputers/My Laptop/New Volume [E]/6th sem/predictive_analysis/assignments/ass3/101903527.csv'
df=pd.read_csv(file_name,nrows=50)
df=df.drop(['Peptide Sequence'],axis=1)
print(df.head())
from pycaret.classification import *
setup(data=df, target='target',silent=True)
cm=compare_models()
print(cm)
df2=pull()
print(df2)
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lightgbm  Light Gradient Boosting Machine    0.5333  0.5000    1.00  0.5333
# dummy                    Dummy Classifier    0.5333  0.5000    1.00  0.5333
# qda       Quadratic Discriminant Analysis    0.5167  0.5500    0.65  0.4500
# lda          Linear Discriminant Analysis    0.5167  0.3250    0.50  0.4333
# et                 Extra Trees Classifier    0.5083  0.4250    0.55  0.5167
# svm                   SVM - Linear Kernel    0.5000  0.0000    0.40  0.2167
# nb                            Naive Bayes    0.4667  0.4125    0.45  0.4000
# knn                K Neighbors Classifier    0.4583  0.4750    0.55  0.4667
# ridge                    Ridge Classifier    0.4417  0.0000    0.45  0.4167
# dt               Decision Tree Classifier    0.4083  0.4000    0.35  0.3667
# rf               Random Forest Classifier    0.4000  0.4125    0.40  0.3333
# lr                    Logistic Regression    0.3833  0.3750    0.35  0.3167
# ada                  Ada Boost Classifier    0.3833  0.3250    0.40  0.3167
# gbc          Gradient Boosting Classifier    0.3083  0.1250    0.25  0.2833
#
#               F1  Kappa     MCC  TT (Sec)
# lightgbm  0.6867   0.00  0.0000     0.018
# dummy     0.6867   0.00  0.0000     0.009
# qda       0.5133   0.09  0.1000     0.017
# lda       0.4433  -0.01 -0.0155     0.015
# et        0.5033  -0.02 -0.0268     0.409
# svm       0.2800   0.00  0.0000     0.014
# nb        0.4067  -0.09 -0.0845     0.014
# knn       0.4500  -0.01  0.0077     0.116
# ridge     0.4133  -0.12 -0.1577     0.012
# dt        0.3467  -0.19 -0.2077     0.014
# rf        0.3600  -0.11 -0.1345     0.461
# lr        0.3300  -0.23 -0.2655     0.228
# ada       0.3500  -0.28 -0.3155     0.084
# gbc       0.2567  -0.36 -0.4077     0.070
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=4581, reg_alpha=0.0, reg_lambda=0.0, silent='warn',
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
#                                     Model  Accuracy  ...     MCC  TT (Sec)
# lightgbm  Light Gradient Boosting Machine    0.5333  ...  0.0000     0.018
# dummy                    Dummy Classifier    0.5333  ...  0.0000     0.009
# qda       Quadratic Discriminant Analysis    0.5167  ...  0.1000     0.017
# lda          Linear Discriminant Analysis    0.5167  ... -0.0155     0.015
# et                 Extra Trees Classifier    0.5083  ... -0.0268     0.409
# svm                   SVM - Linear Kernel    0.5000  ...  0.0000     0.014
# nb                            Naive Bayes    0.4667  ... -0.0845     0.014
# knn                K Neighbors Classifier    0.4583  ...  0.0077     0.116
# ridge                    Ridge Classifier    0.4417  ... -0.1577     0.012
# dt               Decision Tree Classifier    0.4083  ... -0.2077     0.014
# rf               Random Forest Classifier    0.4000  ... -0.1345     0.461
# lr                    Logistic Regression    0.3833  ... -0.2655     0.228
# ada                  Ada Boost Classifier    0.3833  ... -0.3155     0.084
# gbc          Gradient Boosting Classifier    0.3083  ... -0.4077     0.070
#
# [14 rows x 9 columns]

# %%
dfmod=df2['Model']
dfacc=df2['Accuracy']
setup(data=df, target='target',feature_selection = True, feature_selection_method = 'classic', feature_selection_threshold = 0.2, silent=True)
cm = compare_models()
df3=pull()
dfacc1=df3['Accuracy']
setup(data=df, target='target',feature_selection = True, feature_selection_method = 'classic', feature_selection_threshold = 0.5, silent=True)
cm = compare_models()
df4=pull()
dfacc2=df4['Accuracy']
setup(data=df, target='target',feature_selection = True, feature_selection_method = 'boruta', feature_selection_threshold = 0.2, silent=True)
cm = compare_models()
df5=pull()
dfacc3=df5['Accuracy']
setup(data=df, target='target',feature_selection = True, feature_selection_method = 'boruta', feature_selection_threshold = 0.5, silent=True)
cm = compare_models()
df6=pull()
dfacc4=df6['Accuracy']
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# nb                            Naive Bayes    0.8000  0.9250    0.60  0.7500
# et                 Extra Trees Classifier    0.8000  0.8375    0.65  0.7667
# ada                  Ada Boost Classifier    0.6333  0.5000    0.70  0.6000
# ridge                    Ridge Classifier    0.5917  0.0000    0.55  0.5667
# gbc          Gradient Boosting Classifier    0.5917  0.4500    0.45  0.5333
# svm                   SVM - Linear Kernel    0.5750  0.0000    0.55  0.3333
# knn                K Neighbors Classifier    0.5667  0.6125    0.45  0.5833
# dt               Decision Tree Classifier    0.5500  0.5250    0.45  0.4000
# lr                    Logistic Regression    0.5167  0.6250    0.50  0.3833
# qda       Quadratic Discriminant Analysis    0.4917  0.5000    0.55  0.5000
# rf               Random Forest Classifier    0.4750  0.6250    0.40  0.4667
# lda          Linear Discriminant Analysis    0.4417  0.4250    0.45  0.3667
# lightgbm  Light Gradient Boosting Machine    0.4000  0.5000    0.30  0.1000
# dummy                    Dummy Classifier    0.4000  0.5000    0.30  0.1000
#
#               F1  Kappa     MCC  TT (Sec)
# nb        0.6500   0.54  0.5655     0.013
# et        0.6800   0.55  0.5809     0.416
# ada       0.6133   0.28  0.2845     0.085
# ridge     0.5467   0.21  0.1768     0.011
# gbc       0.4500   0.14  0.1577     0.063
# svm       0.4133  -0.05 -0.0577     0.013
# knn       0.4500   0.16  0.2000     0.120
# dt        0.3967   0.04  0.0345     0.013
# lr        0.4200   0.05  0.0345     0.215
# qda       0.4800  -0.02  0.0077     0.014
# rf        0.3900  -0.07 -0.0577     0.460
# lda       0.3767  -0.14 -0.1577     0.013
# lightgbm  0.1500   0.00  0.0000     0.017
# dummy     0.1500   0.00  0.0000     0.011

# %%
dfout=pd.DataFrame({
    'Accuracy wihout Feature Selection':list(dfacc),
    'Accuracy with 0.2 Classic Feature Selection':list(dfacc1),
    'Accuracy with 0.5 Classic Feature Selection':list(dfacc2),
    'Accuracy with 0.2 Boruta Feature Selection':list(dfacc3),
    'Accuracy with 0.5 Boruta Feature Selection':list(dfacc4),
},index=dfmod)
print(dfout)
dfout.to_csv('/content/drive/Othercomputers/My Laptop/New Volume [E]/6th sem/predictive_analysis/assignments/ass3/output-101903527-FeatureSelection.csv')
# Out:
#                                  Accuracy wihout Feature Selection  ...  Accuracy with 0.5 Boruta Feature Selection
# Model                                                               ...
# Light Gradient Boosting Machine                             0.5333  ...                                      0.8000
# Dummy Classifier                                            0.5333  ...                                      0.8000
# Quadratic Discriminant Analysis                             0.5167  ...                                      0.6333
# Linear Discriminant Analysis                                0.5167  ...                                      0.5917
# Extra Trees Classifier                                      0.5083  ...                                      0.5917
# SVM - Linear Kernel                                         0.5000  ...                                      0.5750
# Naive Bayes                                                 0.4667  ...                                      0.5667
# K Neighbors Classifier                                      0.4583  ...                                      0.5500
# Ridge Classifier                                            0.4417  ...                                      0.5167
# Decision Tree Classifier                                    0.4083  ...                                      0.4917
# Random Forest Classifier                                    0.4000  ...                                      0.4750
# Logistic Regression                                         0.3833  ...                                      0.4417
# Ada Boost Classifier                                        0.3833  ...                                      0.4000
# Gradient Boosting Classifier                                0.3083  ...                                      0.4000
#
# [14 rows x 5 columns]

# %% [markdown]
# Q3

# %%
#file_name=sys.argv[1]
file_name='/content/drive/Othercomputers/My Laptop/New Volume [E]/6th sem/predictive_analysis/assignments/ass3/101903527.csv'
df=pd.read_csv(file_name,nrows=50)
df=df.drop(['Peptide Sequence'],axis=1)
print(df.head())
from pycaret.classification import *
setup(data=df, target='target',silent=True)
cm=compare_models()
print(cm)
df2=pull()
print(df2)
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# nb                            Naive Bayes    0.7167  0.6500    0.75  0.7500
# qda       Quadratic Discriminant Analysis    0.6250  0.6250    0.70  0.6833
# ridge                    Ridge Classifier    0.6167  0.0000    0.70  0.6833
# dt               Decision Tree Classifier    0.6000  0.5750    0.70  0.6667
# et                 Extra Trees Classifier    0.6000  0.5750    0.75  0.6333
# lr                    Logistic Regression    0.5667  0.7000    0.60  0.6000
# lda          Linear Discriminant Analysis    0.5667  0.5250    0.65  0.5667
# lightgbm  Light Gradient Boosting Machine    0.5667  0.5000    1.00  0.5667
# dummy                    Dummy Classifier    0.5667  0.5000    1.00  0.5667
# rf               Random Forest Classifier    0.5417  0.6250    0.65  0.5333
# ada                  Ada Boost Classifier    0.5417  0.6750    0.60  0.6000
# svm                   SVM - Linear Kernel    0.4667  0.0000    0.15  0.1500
# gbc          Gradient Boosting Classifier    0.4500  0.4500    0.50  0.4667
# knn                K Neighbors Classifier    0.4083  0.5125    0.45  0.3833
#
#               F1  Kappa     MCC  TT (Sec)
# nb        0.7067   0.38  0.4155     0.014
# qda       0.6467   0.23  0.2577     0.016
# ridge     0.6600   0.18  0.2155     0.014
# dt        0.6500   0.13  0.1500     0.014
# et        0.6633   0.13  0.1500     0.409
# lr        0.5867   0.10  0.1000     0.220
# lda       0.5767   0.09  0.1000     0.015
# lightgbm  0.7167   0.00  0.0000     0.022
# dummy     0.7167   0.00  0.0000     0.010
# rf        0.5767  -0.01 -0.0077     0.461
# ada       0.5700   0.07  0.0923     0.086
# svm       0.1500   0.10  0.1000     0.014
# gbc       0.4567  -0.06 -0.0655     0.073
# knn       0.3700  -0.09 -0.1077     0.114
# GaussianNB(priors=None, var_smoothing=1e-09)
#                                     Model  Accuracy  ...     MCC  TT (Sec)
# nb                            Naive Bayes    0.7167  ...  0.4155     0.014
# qda       Quadratic Discriminant Analysis    0.6250  ...  0.2577     0.016
# ridge                    Ridge Classifier    0.6167  ...  0.2155     0.014
# dt               Decision Tree Classifier    0.6000  ...  0.1500     0.014
# et                 Extra Trees Classifier    0.6000  ...  0.1500     0.409
# lr                    Logistic Regression    0.5667  ...  0.1000     0.220
# lda          Linear Discriminant Analysis    0.5667  ...  0.1000     0.015
# lightgbm  Light Gradient Boosting Machine    0.5667  ...  0.0000     0.022
# dummy                    Dummy Classifier    0.5667  ...  0.0000     0.010
# rf               Random Forest Classifier    0.5417  ... -0.0077     0.461
# ada                  Ada Boost Classifier    0.5417  ...  0.0923     0.086
# svm                   SVM - Linear Kernel    0.4667  ...  0.1000     0.014
# gbc          Gradient Boosting Classifier    0.4500  ... -0.0655     0.073
# knn                K Neighbors Classifier    0.4083  ... -0.1077     0.114
#
# [14 rows x 9 columns]

# %%
dfmod=df2['Model']
dfacc=df2['Accuracy']
setup(data=df, target='target', remove_outliers = True, outliers_threshold = 0.02, silent=True)
cm = compare_models()
df3=pull()
dfacc1=df3['Accuracy']
setup(data=df, target='target', remove_outliers = True, outliers_threshold = 0.04, silent=True)
cm = compare_models()
df4=pull()
dfacc2=df4['Accuracy']
setup(data=df, target='target', remove_outliers = True, outliers_threshold = 0.06, silent=True)
cm = compare_models()
df5=pull()
dfacc3=df5['Accuracy']
setup(data=df, target='target', remove_outliers = True, outliers_threshold = 0.08, silent=True)
cm = compare_models()
df6=pull()
dfacc4=df6['Accuracy']
# Out:
#                                     Model  Accuracy    AUC  Recall   Prec.  \
# lda          Linear Discriminant Analysis    0.7167  0.800    0.75  0.7000
# et                 Extra Trees Classifier    0.5833  0.600    0.55  0.4667
# svm                   SVM - Linear Kernel    0.5500  0.000    0.20  0.1333
# lr                    Logistic Regression    0.5417  0.550    0.60  0.6500
# qda       Quadratic Discriminant Analysis    0.5250  0.525    0.60  0.5500
# ada                  Ada Boost Classifier    0.5250  0.450    0.65  0.4833
# knn                K Neighbors Classifier    0.5083  0.525    0.35  0.4000
# ridge                    Ridge Classifier    0.4750  0.000    0.50  0.4500
# dt               Decision Tree Classifier    0.4667  0.425    0.30  0.3667
# rf               Random Forest Classifier    0.4667  0.550    0.60  0.4000
# nb                            Naive Bayes    0.4583  0.475    0.40  0.4667
# gbc          Gradient Boosting Classifier    0.4000  0.350    0.60  0.4667
# lightgbm  Light Gradient Boosting Machine    0.3500  0.500    0.50  0.1833
# dummy                    Dummy Classifier    0.3500  0.500    0.50  0.1833
#
#               F1  Kappa     MCC  TT (Sec)
# lda       0.7000   0.38  0.4000     0.015
# et        0.4800   0.19  0.2000     0.412
# svm       0.1600   0.00  0.0000     0.014
# lr        0.5633   0.15  0.1577     0.221
# qda       0.5367   0.03  0.0423     0.013
# ada       0.5167  -0.01 -0.0077     0.086
# knn       0.3300   0.09  0.1077     0.117
# ridge     0.4300   0.07  0.0577     0.013
# dt        0.3133  -0.15 -0.1500     0.014
# rf        0.4600  -0.01 -0.0500     0.462
# nb        0.3967  -0.12 -0.1077     0.015
# gbc       0.4633  -0.17 -0.1500     0.070
# lightgbm  0.2667   0.00  0.0000     0.021
# dummy     0.2667   0.00  0.0000     0.012

# %%
dfout=pd.DataFrame({
    'Accuracy wihout Outlier Removal':list(dfacc),
    'Accuracy with 0.2 threshold Outlier Removal':list(dfacc1),
    'Accuracy with 0.4 threshold Outlier Removal':list(dfacc2),
    'Accuracy with 0.6 threshold Outlier Removal':list(dfacc3),
    'Accuracy with 0.8 threshold Outlier Removal':list(dfacc4),
},index=dfmod)
print(dfout)
dfout.to_csv('/content/drive/Othercomputers/My Laptop/New Volume [E]/6th sem/predictive_analysis/assignments/ass3/output-101903527-OutlierRemoval.csv')
# Out:
#                                  Accuracy wihout Outlier Removal  ...  Accuracy with 0.8 threshold Outlier Removal
# Model                                                             ...
# Naive Bayes                                               0.7167  ...                                       0.7167
# Quadratic Discriminant Analysis                           0.6250  ...                                       0.5833
# Ridge Classifier                                          0.6167  ...                                       0.5500
# Decision Tree Classifier                                  0.6000  ...                                       0.5417
# Extra Trees Classifier                                    0.6000  ...                                       0.5250
# Logistic Regression                                       0.5667  ...                                       0.5250
# Linear Discriminant Analysis                              0.5667  ...                                       0.5083
# Light Gradient Boosting Machine                           0.5667  ...                                       0.4750
# Dummy Classifier                                          0.5667  ...                                       0.4667
# Random Forest Classifier                                  0.5417  ...                                       0.4667
# Ada Boost Classifier                                      0.5417  ...                                       0.4583
# SVM - Linear Kernel                                       0.4667  ...                                       0.4000
# Gradient Boosting Classifier                              0.4500  ...                                       0.3500
# K Neighbors Classifier                                    0.4083  ...                                       0.3500
#
# [14 rows x 5 columns]

# %% [markdown]
# Q4

# %%
#file_name=sys.argv[1]
file_name='/content/drive/Othercomputers/My Laptop/New Volume [E]/6th sem/predictive_analysis/assignments/ass3/101903527.csv'
df=pd.read_csv(file_name)
df=df.drop(['Peptide Sequence'],axis=1)
print(df.head())
from pycaret.classification import *
setup(data=df, target='target',silent=True)
cm=compare_models()
print(cm)
df2=pull()
print(df2)
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# gbc          Gradient Boosting Classifier    0.7406  0.7945  0.6495  0.7963
# rf               Random Forest Classifier    0.7401  0.7982  0.6779  0.7767
# lightgbm  Light Gradient Boosting Machine    0.7346  0.7949  0.6992  0.7552
# ada                  Ada Boost Classifier    0.7239  0.7748  0.6495  0.7656
# et                 Extra Trees Classifier    0.7212  0.7852  0.6881  0.7397
# knn                K Neighbors Classifier    0.6835  0.7423  0.6534  0.6972
# lda          Linear Discriminant Analysis    0.6415  0.6872  0.6006  0.6573
# dt               Decision Tree Classifier    0.6368  0.6369  0.6314  0.6405
# ridge                    Ridge Classifier    0.6305  0.0000  0.5887  0.6461
# lr                    Logistic Regression    0.6273  0.6712  0.5966  0.6384
# nb                            Naive Bayes    0.5628  0.6962  0.1855  0.7734
# svm                   SVM - Linear Kernel    0.5117  0.0000  0.6052  0.4440
# dummy                    Dummy Classifier    0.5018  0.5000  1.0000  0.5018
# qda       Quadratic Discriminant Analysis    0.5014  0.5000  0.8911  0.5019
#
#               F1   Kappa     MCC  TT (Sec)
# gbc       0.7149  0.4815  0.4904     0.932
# rf        0.7231  0.4805  0.4853     0.720
# lightgbm  0.7253  0.4694  0.4716     0.189
# ada       0.7025  0.4482  0.4537     0.289
# et        0.7122  0.4424  0.4444     0.694
# knn       0.6738  0.3672  0.3686     0.149
# lda       0.6272  0.2833  0.2848     0.083
# dt        0.6354  0.2737  0.2742     0.062
# ridge     0.6155  0.2611  0.2627     0.027
# lr        0.6165  0.2548  0.2556     0.661
# nb        0.2976  0.1279  0.1982     0.029
# svm       0.4487  0.0218  0.0202     0.088
# dummy     0.6682  0.0000  0.0000     0.022
# qda       0.6415  0.0001 -0.0020     0.054
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=6122, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)
#                                     Model  Accuracy  ...     MCC  TT (Sec)
# gbc          Gradient Boosting Classifier    0.7406  ...  0.4904     0.932
# rf               Random Forest Classifier    0.7401  ...  0.4853     0.720
# lightgbm  Light Gradient Boosting Machine    0.7346  ...  0.4716     0.189
# ada                  Ada Boost Classifier    0.7239  ...  0.4537     0.289
# et                 Extra Trees Classifier    0.7212  ...  0.4444     0.694
# knn                K Neighbors Classifier    0.6835  ...  0.3686     0.149
# lda          Linear Discriminant Analysis    0.6415  ...  0.2848     0.083
# dt               Decision Tree Classifier    0.6368  ...  0.2742     0.062
# ridge                    Ridge Classifier    0.6305  ...  0.2627     0.027
# lr                    Logistic Regression    0.6273  ...  0.2556     0.661
# nb                            Naive Bayes    0.5628  ...  0.1982     0.029
# svm                   SVM - Linear Kernel    0.5117  ...  0.0202     0.088
# dummy                    Dummy Classifier    0.5018  ...  0.0000     0.022
# qda       Quadratic Discriminant Analysis    0.5014  ... -0.0020     0.054
#
# [14 rows x 9 columns]

# %%
dfmod=df2['Model']
dfacc=df2['Accuracy']
setup(data=df, target='target', pca = True, pca_method = 'linear', silent=True)
cm = compare_models()
df3=pull()
dfacc1=df3['Accuracy']
setup(data=df, target='target',pca = True, pca_method = 'kernel', silent=True)
cm = compare_models()
df4=pull()
dfacc2=df4['Accuracy']
setup(data=df, target='target',pca = True, pca_method = 'incremental', silent=True)
cm = compare_models()
df5=pull()
dfacc3=df5['Accuracy']
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# et                 Extra Trees Classifier    0.7263  0.7884  0.6324  0.7596
# rf               Random Forest Classifier    0.7232  0.7785  0.6308  0.7545
# lightgbm  Light Gradient Boosting Machine    0.7172  0.7669  0.6604  0.7271
# gbc          Gradient Boosting Classifier    0.7109  0.7579  0.5864  0.7596
# qda       Quadratic Discriminant Analysis    0.7046  0.7582  0.5732  0.7563
# nb                            Naive Bayes    0.6939  0.7495  0.5148  0.7771
# ada                  Ada Boost Classifier    0.6895  0.7307  0.5822  0.7200
# knn                K Neighbors Classifier    0.6804  0.7298  0.6365  0.6808
# dt               Decision Tree Classifier    0.6309  0.6296  0.5946  0.6228
# lr                    Logistic Regression    0.6008  0.6271  0.5264  0.5984
# ridge                    Ridge Classifier    0.5996  0.0000  0.5239  0.5971
# lda          Linear Discriminant Analysis    0.5996  0.6273  0.5239  0.5971
# svm                   SVM - Linear Kernel    0.5188  0.0000  0.4927  0.5061
# dummy                    Dummy Classifier    0.5184  0.5000  0.0000  0.0000
#
#               F1   Kappa     MCC  TT (Sec)
# et        0.6899  0.4487  0.4549     0.583
# rf        0.6868  0.4423  0.4483     0.878
# lightgbm  0.6919  0.4318  0.4337     0.184
# gbc       0.6615  0.4164  0.4273     0.843
# qda       0.6514  0.4032  0.4156     0.015
# nb        0.6184  0.3796  0.4029     0.016
# ada       0.6433  0.3739  0.3809     0.261
# knn       0.6574  0.3585  0.3598     0.125
# dt        0.6079  0.2596  0.2602     0.046
# lr        0.5596  0.1972  0.1990     0.177
# ridge     0.5577  0.1947  0.1965     0.016
# lda       0.5577  0.1947  0.1965     0.018
# svm       0.4978  0.0360  0.0369     0.026
# dummy     0.0000  0.0000  0.0000     0.011

# %%
dfout=pd.DataFrame({
    'Accuracy wihout PCA':list(dfacc),
    'Accuracy with linear PCA':list(dfacc1),
    'Accuracy with kernel PCA':list(dfacc2),
    'Accuracy with incremental PCA':list(dfacc3),
},index=dfmod)
print(dfout)
dfout.to_csv('/content/drive/Othercomputers/My Laptop/New Volume [E]/6th sem/predictive_analysis/assignments/ass3/output-101903527-PCA.csv')
# Out:
#                                  Accuracy wihout PCA  ...  Accuracy with incremental PCA
# Model                                                 ...
# Gradient Boosting Classifier                  0.7406  ...                         0.7263
# Random Forest Classifier                      0.7401  ...                         0.7232
# Light Gradient Boosting Machine               0.7346  ...                         0.7172
# Ada Boost Classifier                          0.7239  ...                         0.7109
# Extra Trees Classifier                        0.7212  ...                         0.7046
# K Neighbors Classifier                        0.6835  ...                         0.6939
# Linear Discriminant Analysis                  0.6415  ...                         0.6895
# Decision Tree Classifier                      0.6368  ...                         0.6804
# Ridge Classifier                              0.6305  ...                         0.6309
# Logistic Regression                           0.6273  ...                         0.6008
# Naive Bayes                                   0.5628  ...                         0.5996
# SVM - Linear Kernel                           0.5117  ...                         0.5996
# Dummy Classifier                              0.5018  ...                         0.5188
# Quadratic Discriminant Analysis               0.5014  ...                         0.5184
#
# [14 rows x 4 columns]

# %% [markdown]
# Q5

# %%
#file_name=sys.argv[1]
file_name='/content/drive/Othercomputers/My Laptop/New Volume [E]/6th sem/predictive_analysis/assignments/ass3/101903527.csv'
df=pd.read_csv(file_name)
df=df.drop(['Peptide Sequence'],axis=1)
print(df.head())
# Out:
#    len  Aliphatic_index  Boman_index  ...  KideraFactor  isoelectric pt.  target
# 0   15       123.333333     0.684000  ...      0.072000         9.298295       0
# 1   24       101.250000    -0.277917  ...     -0.092500         5.454228       1
# 2   10       146.000000    -1.232000  ...     -0.729000         9.700016       1
# 3   15       130.000000    -0.642667  ...      0.118667         3.749972       1
# 4   15       142.666667    -1.236000  ...     -0.458667         4.181183       0
#
# [5 rows x 31 columns]

# %%
os.getcwd()
os.chdir('/content/drive/Othercomputers/My Laptop/New Volume [E]/6th sem/predictive_analysis/assignments/ass3')

# %%
rfModel = create_model('rf')
plot_model(rfModel,plot='confusion_matrix',save=True)
# Out:
# 'Confusion Matrix.png'

# %%
os.rename('Confusion Matrix.png','output-101903527-ConfusionMatrix.png')

# %% [markdown]
# Q6

# %%
#file_name=sys.argv[1]
file_name='/content/drive/Othercomputers/My Laptop/New Volume [E]/6th sem/predictive_analysis/assignments/ass3/101903527.csv'
df=pd.read_csv(file_name,nrows=50)
df=df.drop(['Peptide Sequence'],axis=1)
setup(data=df, target='target',silent=True)
rfModel = create_model('rf')
os.getcwd()
os.chdir('/content/drive/Othercomputers/My Laptop/New Volume [E]/6th sem/predictive_analysis/assignments/ass3')
plot_model(rfModel,plot='learning',save=True)
os.rename('Learning Curve.png','output-101903527-Learning Curve.png')

# %% [markdown]
# Q7

# %%
#file_name=sys.argv[1]
file_name='/content/drive/Othercomputers/My Laptop/New Volume [E]/6th sem/predictive_analysis/assignments/ass3/101903527.csv'
df=pd.read_csv(file_name,nrows=50)
df=df.drop(['Peptide Sequence'],axis=1)
setup(data=df, target='target',silent=True)
rfModel = create_model('rf')
os.getcwd()
os.chdir('/content/drive/Othercomputers/My Laptop/New Volume [E]/6th sem/predictive_analysis/assignments/ass3')
plot_model(rfModel,plot='auc',save=True)
os.rename('AUC.png','output-101903527-AUC.png')

# %% [markdown]
# Q8

# %%
from pycaret.datasets import get_data
from pycaret.classification import *

#file_name=sys.argv[1]
file_name='/content/drive/Othercomputers/My Laptop/New Volume [E]/6th sem/predictive_analysis/assignments/ass3/101903527.csv'
df=pd.read_csv(file_name,nrows=50)
df=df.drop(['Peptide Sequence'],axis=1)
setup(data=df, target='target',silent=True)
rfModel = create_model('rf')
os.getcwd()
os.chdir('/content/drive/Othercomputers/My Laptop/New Volume [E]/6th sem/predictive_analysis/assignments/ass3')
plot_model(rfModel, plot='boundary',save=True)
os.rename('Decision Boundary.png','output-101903527-Decision Boundary.png')

# %% [markdown]
# Q9

# %%
from pycaret.datasets import get_data
from pycaret.classification import *

#file_name=sys.argv[1]
file_name='/content/drive/Othercomputers/My Laptop/New Volume [E]/6th sem/predictive_analysis/assignments/ass3/101903527.csv'
df=pd.read_csv(file_name,nrows=50)
df=df.drop(['Peptide Sequence'],axis=1)
setup(data=df, target='target',silent=True)
rfModel = create_model('rf')
os.getcwd()
os.chdir('/content/drive/Othercomputers/My Laptop/New Volume [E]/6th sem/predictive_analysis/assignments/ass3')
plot_model(rfModel, plot='feature',save=True)
os.rename('Feature Importance.png','output-101903527-Feature Importance.png')

# %%
"""
Created on Sun Feb 20 09:50:04 2022

@author: 
ADITI
101903527
2CO20
"""
import pandas as pd
import os
import sys
import pytz
from pycaret.datasets import get_data
from pycaret.classification import *

os.getcwd()
os.chdir('/content/drive/Othercomputers/My Laptop/New Volume [E]/6th sem/predictive_analysis/assignments/ass3')

#file_name=sys.argv[1]

file_name='/content/drive/Othercomputers/My Laptop/New Volume [E]/6th sem/predictive_analysis/assignments/ass3/101903527.csv'
df=pd.read_csv(file_name,nrows=50)
df=df.drop(['Peptide Sequence'],axis=1)
print(df.head())
from pycaret.classification import *
setup(data=df, target='target',silent=True)
cm=compare_models()
print(cm)
df2=pull()
print(df2)
dfmod=df2['Model']
dfacc=df2['Accuracy']

#Q1

setup(data=df, target='target', normalize = True, normalize_method = 'zscore', silent=True)
cm = compare_models()
df3=pull()
dfacc1=df3['Accuracy']

setup(data=df, target='target', normalize = True, normalize_method = 'minmax', silent=True)
cm = compare_models()
df4=pull()
dfacc2=df4['Accuracy']


setup(data=df, target='target', normalize = True, normalize_method = 'maxabs', silent=True)
cm = compare_models()
df5=pull()
dfacc3=df5['Accuracy']

setup(data=df, target='target', normalize = True, normalize_method = 'robust', silent=True)
cm = compare_models()
df6=pull()
dfacc4=df6['Accuracy']

dfout=pd.DataFrame({
    'Accuracy wihout Normalization':list(dfacc),
    'Accuracy with zscore Normalization':list(dfacc1),
    'Accuracy with minmax Normalization':list(dfacc2),
    'Accuracy with maxabs Normalization':list(dfacc3),
    'Accuracy with robust Normalization':list(dfacc4),
},index=dfmod)
print(dfout)

dfout.to_csv('output-101903527-Normalization.csv')

#Q2


setup(data=df, target='target',feature_selection = True, feature_selection_method = 'classic', feature_selection_threshold = 0.2, silent=True)
cm = compare_models()
df3=pull()
dfacc1=df3['Accuracy']
setup(data=df, target='target',feature_selection = True, feature_selection_method = 'classic', feature_selection_threshold = 0.5, silent=True)
cm = compare_models()
df4=pull()
dfacc2=df4['Accuracy']
setup(data=df, target='target',feature_selection = True, feature_selection_method = 'boruta', feature_selection_threshold = 0.2, silent=True)
cm = compare_models()
df5=pull()
dfacc3=df5['Accuracy']
setup(data=df, target='target',feature_selection = True, feature_selection_method = 'boruta', feature_selection_threshold = 0.5, silent=True)
cm = compare_models()
df6=pull()
dfacc4=df6['Accuracy']

dfout=pd.DataFrame({
    'Accuracy wihout Feature Selection':list(dfacc),
    'Accuracy with 0.2 Classic Feature Selection':list(dfacc1),
    'Accuracy with 0.5 Classic Feature Selection':list(dfacc2),
    'Accuracy with 0.2 Boruta Feature Selection':list(dfacc3),
    'Accuracy with 0.5 Boruta Feature Selection':list(dfacc4),
},index=dfmod)
print(dfout)
dfout.to_csv('output-101903527-FeatureSelection.csv')

#Q3


setup(data=df, target='target', remove_outliers = True, outliers_threshold = 0.02, silent=True)
cm = compare_models()
df3=pull()
dfacc1=df3['Accuracy']
setup(data=df, target='target', remove_outliers = True, outliers_threshold = 0.04, silent=True)
cm = compare_models()
df4=pull()
dfacc2=df4['Accuracy']
setup(data=df, target='target', remove_outliers = True, outliers_threshold = 0.06, silent=True)
cm = compare_models()
df5=pull()
dfacc3=df5['Accuracy']
setup(data=df, target='target', remove_outliers = True, outliers_threshold = 0.08, silent=True)
cm = compare_models()
df6=pull()
dfacc4=df6['Accuracy']

dfout=pd.DataFrame({
    'Accuracy wihout Outlier Removal':list(dfacc),
    'Accuracy with 0.2 threshold Outlier Removal':list(dfacc1),
    'Accuracy with 0.4 threshold Outlier Removal':list(dfacc2),
    'Accuracy with 0.6 threshold Outlier Removal':list(dfacc3),
    'Accuracy with 0.8 threshold Outlier Removal':list(dfacc4),
},index=dfmod)
print(dfout)
dfout.to_csv('output-101903527-OutlierRemoval.csv')

#Q4


setup(data=df, target='target', pca = True, pca_method = 'linear', silent=True)
cm = compare_models()
df3=pull()
dfacc1=df3['Accuracy']
setup(data=df, target='target',pca = True, pca_method = 'kernel', silent=True)
cm = compare_models()
df4=pull()
dfacc2=df4['Accuracy']
setup(data=df, target='target',pca = True, pca_method = 'incremental', silent=True)
cm = compare_models()
df5=pull()
dfacc3=df5['Accuracy']

dfout=pd.DataFrame({
    'Accuracy wihout PCA':list(dfacc),
    'Accuracy with linear PCA':list(dfacc1),
    'Accuracy with kernel PCA':list(dfacc2),
    'Accuracy with incremental PCA':list(dfacc3),
},index=dfmod)
print(dfout)
dfout.to_csv('output-101903527-PCA.csv')



setup(data=df, target='target',silent=True)
rfModel = create_model('rf')

#Q5

plot_model(rfModel,plot='confusion_matrix',save=True)
os.rename('Confusion Matrix.png','output-101903527-ConfusionMatrix.png')

#Q6

plot_model(rfModel,plot='learning',save=True)
os.rename('Learning Curve.png','output-101903527-Learning Curve.png')

#Q7

plot_model(rfModel,plot='auc',save=True)
os.rename('AUC.png','output-101903527-AUC.png')


# Q8

plot_model(rfModel, plot='boundary',save=True)
os.rename('Decision Boundary.png','output-101903527-Decision Boundary.png')


# Q9

plot_model(rfModel, plot='feature',save=True)
os.rename('Feature Importance.png','output-101903527-Feature Importance.png')
